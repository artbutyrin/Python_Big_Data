# %% [markdown]
# <a href="https://colab.research.google.com/github/artbutyrin/Python_Big_Data/blob/main/python_practice_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # I. Змінні та памʼять.

# %% [markdown]
# 1. Створити змінні, що посилаються на два цілих числа, що однакові за значенням, де значення належить проміжку від -5 до 256. Перевірте, чи будуть ці змінні рівні тільки за значенням або ж ще будуть посилатися на один і той самий обʼєкт в памʼяті? Наведіть код та дайте текстову відповідь нижче.

# %%
a = 100
b = 100
c = (a == b)
d = (a is b)
print("чи будуть ці змінні рівні тільки за значенням - ", c)
print("чи будуть посилатися на один і той самий обʼєкт в памʼяті - ", d)
# Out:
# чи будуть ці змінні рівні тільки за значенням -  True
# чи будуть посилатися на один і той самий обʼєкт в памʼяті -  True

# %% [markdown]
# Дві змінні, що за значенням однакові, та однаково посилаються на один і той самий об'єкт в пам'яті чудово виводять значення True, що показує що вони і так і так рівні

# %% [markdown]
# 2. За допомогою якої функції можна перевірити належність змінної до вказаного типу даних (напр. чи змінна True посилається на значення булевого та цілочисленого типу)?

# %%
var = True
type_var = type(var)
print(type_var)
is_bool = (type_var == bool)
is_int = (type_var == int)
print("Перевірка ", is_bool, " та ", is_int)
# Out:
# <class 'bool'>
# Перевірка  True  та  False
# True
# True
# 1

# %% [markdown]
# # II. Цілі числа та числа з рухомою комою

# %% [markdown]
# 3. Створити дві змінні, що посилаються на будь-які ціле число та число з рухомою комою та продемонструвати такі арифметичні операції: додавання, віднімання, ділення, множення, ділення без залишку, ділення по модулю, приведення до ступеню. Всі результати операцій вивести на екран.

# %%
a = 9
b = 3.5
print("+", a+b)
print("-", a-b)
print("*", a*b)
print("/", a/b)
print("без залишку //", a//b)
print("модуль %", a%b)
print("**", a**b)
# Out:
# + 12.5
# - 5.5
# * 31.5
# / 2.5714285714285716
# без залишку // 2.0
# залишок % 2.0
# ** 2187.0

# %% [markdown]
# 4. Використовуючи змінні з вправи 3, продемонструйте механізм явного перетворення типів, де числа з рухомою комою перетворюються на цілі числа. Також визначте змінну, що посилається на значення булевого типу і спробуйте явно привести її до цілого числа.

# %%
a = 9
b = 3.5
c = int(b)
d = float(a)
print("порівняння ", a == d)
print("порівняння ", b == c)
f = True
int_f = int(f)
print("true -> 1 \\ ", f, "->", int_f)
# Out:
# порівняння  True
# порівняння  False
# true -> 1 \  True -> 1

# %% [markdown]
# # IІІ. Рядки (String).

# %% [markdown]
# 5. Створити пустий рядок двома різними способами.

# %%
a = ""
b = str()
c = (len(a) == 0)
d = (len(b) == 0)
e = (a == b)

# %% [markdown]
# *6*. Створити рядок з апострофом. Зробити його сирим. Вивести обидва рядка на екран.

# %%
print('''I'm learning Python''')
print("\n")
print(r"cd мовчки ' \n")
# Out:
# I'm learning Python
#
#
# cd мовчки ' \n

# %% [markdown]
# 7. Створити змінну, що буде посилатися на Ваше прізвище латинкою. Створити форматований рядок, який буде мати вигляд "My surname is ______", де на місці нижніх підкреслень буде Ваше прізвище зі змінної.

# %%
my_name = "Butyrin"
print(f"My name is {my_name}")
# Out:
# My name is Butyrin

# %% [markdown]
# 8. Маючи рядок "My dog is crazy." перетворити його на список ["my", "dog", "is", "crazy"]

# %%
import builtins
s = "My dog is crazy."
result = s.lower().replace(".", "").split()
builtins.print(result)
# Out:
# ['my', 'dog', 'is', 'crazy']

# %% [markdown]
# # IV. Робота зі списками.

# %% [markdown]
# 9. Створити список двома різними за синтаксисом способами. За допомогою вбудованої функції обчисліть довжину одного з них.

# %%
import builtins
l1 = [1, 2, 3, 4]
l2 = list([5, 6, 7, 8])
length = len(l2)
builtins.print(l1)
builtins.print(l2)
builtins.print(length)
# Out:
# [1, 2, 3, 4]
# [5, 6, 7, 8]
# 4

# %% [markdown]
# 10. Створіть два списка та за допомогою спеціального методу додайте другий з них в якості останнього елемента першого.

# %%
import builtins
l1 = ["a", "b", "c", "d"]
l2 = [10, 20, 30]

builtins.print(l1, l2)
l1.append(l2)

builtins.print("l1 =", l1)
builtins.print("Останній елемент:", l1[-1])
builtins.print("Тип останнього елемента:", type(l1[-1]))
# Out:
# ['a', 'b', 'c', 'd'] [10, 20, 30]
# l1 = ['a', 'b', 'c', 'd', [10, 20, 30]]
# Останній елемент: [10, 20, 30]
# Тип останнього елемента: <class 'list'>

# %% [markdown]
# 11. Створіть список, де елементами цього списку також є списки. Отримай перший елемент з останнього рядка та виведи значення на екран.

# %%
import builtins
m = [
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 9]
]

last = m[-1]
first_el = last[0]
builtins.print(first_el)
# Out:
# 7

# %% [markdown]
# 12. Створіть список з десяти елементів різного типу. Отримайте всі елементи, окрім двох перших та двох останніх та збережіть їх в новій змінній.

# %%
import builtins
my_list = [6, 9.8, "h", True, [1, 2, 3],
 ("a", "b"), {"key": "value"}, None, 2 + 3j, {"apple", "banana"}]

builtins.print(my_list)
new_list = my_list[2:-2]

builtins.print("без двох перших і двох останніх:")
builtins.print(new_list)

builtins.print(f"\nДовжина початкового списку: {len(my_list)}")
builtins.print(f"Довжина нового списку: {len(new_list)}")
# Out:
# [6, 9.8, 'h', True, [1, 2, 3], ('a', 'b'), {'key': 'value'}, None, (2+3j), {'apple', 'banana'}]
# без двох перших і двох останніх:
# ['h', True, [1, 2, 3], ('a', 'b'), {'key': 'value'}, None]
#
# Довжина початкового списку: 10
# Довжина нового списку: 6

# %% [markdown]
# # V. Робота з кортежами.

# %% [markdown]
# 14. Створити кортеж з один елементом.

# %%
import builtins
t = "h",
builtins.print(type(t))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2190789095.py in <cell line: 0>()
#       2 t = "h",
#       3 v = type(t)
# ----> 4 builtins.print(v)
#
# TypeError: 'type' object is not iterable

# %% [markdown]
# 15.

# %% [markdown]
# Схожості: зберігають послідовність елементів, можуть містити елементи різних типів, підтримують індексацію, можуть вкладатися один в один.

# %% [markdown]
# 16. Створіть кортеж з 11ти елементів чисел з рухомою комою та отримайте кожен парний за індексом елемент в зворотньому порядку. Наприклад, маючи (1.2, 2.3, 3.3, 4.3, 5.3, 6.3, 7.3, 8.3, 9.3, 0.3), отримати (0.3, 8.3, 6.3, 4.3, 2.3). Результат збережіть в нову змінну та виведіть на екран.

# %%
t = (1.2, 2.3, 3.3, 4.3, 5.3, 6.3, 7.3, 8.3, 9.3, 0.3, 10.5)
result = t[::2][::-1]
print(result)

# %% [markdown]
# # VI. Множини (Set).

# %% [markdown]
# 17. Створити множину без елементів. Після цого за допомогою методу додайте кілька різних елементів до множини. Чи множини є змінним типом даних?

# %%
s = set()
s.add(2)
s.add("h")
print(s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2832243064.py in <cell line: 0>()
#       2 s.add(2)
#       3 s.add("h")
# ----> 4 print(s)
#
# TypeError: 'list' object is not callable

# %% [markdown]
# Так, бо до множини можна додавати елементи

# %% [markdown]
# 18. Створити множину, маючи список my_list = [1, 1, 2, 67, 67, 8, 9]. Пояснити, чому "зникли" деякі елементи.

# %%
my_list = [1, 1, 2, 67, 67, 8, 9]
my_set = set(my_list)
print(my_set)

# %% [markdown]
# Тому що set зберігає лише унікальні елементи

# %% [markdown]
# 19. Створіть дві множини. Продемонстуйте над ними операції: обʼєднання, різниці, пересічі та симетричної різниці. Використовуйте методи, що не змінюють множини, а створюють нові.

# %%
A = {1, 2, 3, 4}
B = {3, 4, 5, 6}

union_set = A.union(B)
intersection_set = A.intersection(B)
difference_set = A.difference(B)
symmetric_difference_set = A.symmetric_difference(B)

print(A)
print(B)
print(union_set)
print(intersection_set)
print(difference_set)
print(symmetric_difference_set)

# %% [markdown]
# # VII. Словники (Dictionary).

# %% [markdown]
# 20. Створіть пустий словник. До нього додайте чотири пари елементів такі, щоб їхні ключі були різних типів. Чи може список бути ключем? Чому?

# %%
dict = {}
dict[1] = "int"
dict[3.14] = "float"
dict[True] = "bool"
dict["str"] = "str"

# %% [markdown]
# Список не може бути ключем, бо ключі словника повинні бути незмінними наче хешованими типами

# %% [markdown]
# 21. Створіть словник, де значенням в одній з пар теж буде словник, який теж має вкладений словник. Виведіть на екран значення, що міститься в словнику, що знаходиться на найнижчому рівні ієрархії вкладеності (найбільш внутрішній).

# %%
print()
n_dict = {
    "lvl1": {
        "lvl2": {
            "lvl3": {
                "deep" : "deepVAL"
            }
        }
    }
}

result = n_dict["lvl1"]["lvl2"]["lvl3"]["deep"]
print(result)

# %% [markdown]
# # Вітаю! Ви велика(ий) молодець, що впоралась(вся). Похваліть себе та побалуйте чимось приємним. Я Вами пишаюся.
