# %% [markdown]
# WARNING
#
# This material has been reproduced and communicated to you by or on behalf of Grid Dynamics and its Technical Trainer Antonina Kalchenko.
#
# Any further reproduction or communication of this material by you may be the subject of copyright protection.
#
# Copyright © Antonina Kalchenko, Grid Dynamics 2025

# %% [markdown]
# # **Data Visualization**
#
# Data Visualization can be seen as a powerful communication tool which helps in Data Analytics through **transforming raw data and numerical figures into aesthetically appealing visual objects**.
#
# It helps in presenting complex information in a logical, simple, comprehensible and interactive form. Thus, Data Visualization is also a form of organizing data in compelling and digestible forms.

# %% [markdown]
# ## **Bad Visualizations**

# %% [markdown]
# 1. ![image.png](data:image/png;base64,...)

# %% [markdown]
# CONCLUSION:
#
# 1. Include title.
# 2. Check if the trend you want to show is clear.
# 3. Use comparable measuruments. Scale your graph.
# 4. Start each axis from 0.
# 5. Choose appropriate methods of visualizations. (Look through different types of graphs available).
# E.g. https://datavizcatalogue.com/

# %% [markdown]
# 2. ![image.png](data:image/png;base64,...)

# %% [markdown]
# CONCLUSIONS:
#
# 1. Use simple and short title.
# 2. Do not use a lot of colors. Use a shadow pallette for several colors.
# 3. Choose no more than 10 categories.
# 4. Show the chart to your colleague and check if he/she undertands the idea after no more than 10-15sec.
# 5. Use well-known terms.
# 6. Sort your data to support your conclusion.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# CONCLUSIONS:
#
# 1. Use corporate design and pallette.
# 2. Use 1-2 fonts only.
# 3. Include proper links to the resources.
# 4. Check if your syntax and spelling are correct.
# 5. Check the grid.
# 6. Always include name for axis. And measurement types.
# 7. Names of categories should be equal.

# %% [markdown]
# ## **What graphs and when to use them?**

# %% [markdown]
# 1. Line graph
#
# *Continuous numerical data over time*
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 2. Scatter plot
#
# *Show dependance of one continuous numerical set to the other.*
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 3. Bar chart
#
# *Show dependency of non-dependent categories (e.g. cat, dog, giraffe) and numbers.*
#
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 3.a Histogram
#
# *Specific type of bar chart, where the categories are ranges of numbers (bins). Histograms therefore show combined continuous data.*
#
# ![image.png](data:image/png;base64,...
# )
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 4. Pie chart
#
# *To show the ratio of categories. They should sum up into 1 or 100%*
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **Matplotlib and pyplot**
#
# https://matplotlib.org/stable/tutorials/introductory/quick_start.html
#
#
# https://realpython.com/python-matplotlib-guide/

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# A Figure object is the outermost container for a matplotlib graphic, which can contain multiple Axes objects. One source of confusion is the name: an Axes actually translates into what we think of as an individual plot or graph (rather than the plural of “axis,” as we might expect).
#
# You can think of the Figure object as a box-like container holding one or more Axes (actual plots). Below the Axes in the hierarchy are smaller objects such as tick marks, individual lines, legends, and text boxes. Almost every “element” of a chart is its own manipulable Python object, all the way down to the ticks and labels:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16]) # simplest example
plt.show()

# %%
fig = plt.figure()  # an empty figure with no Axes

# %%
fig, ax = plt.subplots()  # a figure with a single Axes

# %%
fig, axs = plt.subplots(2, 2)  # a figure with a 2x2 grid of Axes

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
X = np.random.randint(low=1, high=11, size=50)
Y = X + np.random.randint(1, 5, size=X.size)
data = np.column_stack((X, Y))
data
# Out:
# array([[10, 13],
#        [ 1,  3],
#        [ 7, 10],
#        [ 1,  2],
#        [10, 13],
#        [ 7, 10],
#        [ 3,  5],
#        [10, 12],
#        [ 7, 11],
#        [ 7,  8],
#        [ 3,  4],
#        [ 7, 11],
#        [10, 11],
#        [ 2,  5],
#        [ 5,  7],
#        [ 4,  5],
#        [ 9, 12],
#        [ 7,  8],
#        [ 6,  7],
#        [ 8, 11],
#        [ 9, 13],
#        [ 7,  8],
#        [ 2,  5],
#        [ 1,  3],
#        [ 1,  2],
#        [ 7,  9],
#        [ 5,  9],
#        [ 4,  6],
#        [10, 12],
#        [ 3,  4],
#        [ 2,  3],
#        [ 2,  3],
#        [ 8, 12],
#        [ 1,  2],
#        [ 4,  8],
#        [ 9, 11],
#        [ 5,  6],
#        [ 8, 12],
#        [ 7, 10],
#        [ 3,  7],
#        [ 7,  8],
#        [ 4,  5],
#        [ 6,  8],
#        [ 7, 11],
#        [10, 11],
#        [ 9, 11],
#        [ 3,  6],
#        [10, 11],
#        [ 6, 10],
#        [ 2,  4]])

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(8, 4)) # or fig, axes
fig, ax1, ax2
# Out:
# (<Figure size 800x400 with 2 Axes>, <Axes: >, <Axes: >)

# %%
(fig.axes[0] is ax1, fig.axes[1] is ax2)
# Out:
# (True, True)

# %%
ax1.scatter(x=X, y=Y, marker='*', c='r', edgecolor='b')
ax1.set_title('Scatter: $x$ versus $y$')
ax1.set_xlabel('$x$')
ax1.set_ylabel('$y$')
ax1.grid(color='g', linestyle='-', linewidth=1)
fig

# %%
ax2.hist(data, bins=np.arange(data.min(), data.max()), label=('x', 'y'))
ax2.legend(loc=(0.7, 0.8))
ax2.yaxis.tick_right()
fig

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
gridsize = (3, 2)
fig = plt.figure(figsize=(12, 8))
ax1 = plt.subplot2grid(gridsize, (0, 0), colspan=2, rowspan=2)
ax2 = plt.subplot2grid(gridsize, (2, 0))
ax3 = plt.subplot2grid(gridsize, (2, 1))

# %%
# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
sizes = [15.5, 30, 45, 10]
explode = (0, 0.1, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %% [markdown]
# HW: Read about float representation in Python here: https://realpython.com/how-to-python-f-string-format-float/

# %%
labels_sizes_dict = {'Frogs': 15.5, 'Hogs': 30, 'Dogs': 45, 'Logs': 10}
labels_sizes_dict_sorted = dict(sorted(labels_sizes_dict.items(), key=lambda item: item[1]))
print(labels_sizes_dict_sorted)
# Out:
# {'Logs': 10, 'Frogs': 15.5, 'Hogs': 30, 'Dogs': 45}

# %%
explode = (0, 0, 0.1, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(labels_sizes_dict_sorted.values(), explode=explode,
        labels=labels_sizes_dict_sorted.keys(), autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %% [markdown]
# ### **Seaborn**
#
# https://seaborn.pydata.org/tutorial/introduction.html
#
# Seaborn is a library for making statistical graphics in Python. It builds on top of matplotlib and integrates closely with pandas data structures.

# %%
# Import seaborn
import seaborn as sns

# %%
tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.scatterplot(x=tips["total_bill"], y=tips["tip"])
plt.show()

# %%
sns.regplot(x="total_bill", y="tip", data=tips) # Linear regression
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.relplot(data=tips, x="total_bill", y="tip", hue="smoker")

# %%
# Draw a nested boxplot to show bills by day and time
sns.boxplot(x="day", y="total_bill", data=tips,
            hue="smoker", palette=["m", "g"],)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(data=tips, x="day", y="total_bill", hue="smoker",
               split=True, inner="quart", linewidth=1,
               palette={"Yes": "b", "No": ".85"})
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
penguins = sns.load_dataset("penguins")
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.histplot(penguins, x="flipper_length_mm", bins=200)
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Count'>

# %%
sns.pairplot(penguins, hue="species")

# %% [markdown]
# ### **Examples of EDA to check out**
#
# 1. https://www.kaggle.com/code/joshuaswords/awesome-data-visualisation-student-results?scriptVersionId=57181038
# 2. https://www.kaggle.com/code/joshuaswords/netflix-data-visualization
# 3. https://www.kaggle.com/code/benhamner/python-data-visualizations
